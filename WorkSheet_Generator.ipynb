# %% [markdown]
# ---

# %%
# %%capture
# # update or install the necessary libraries
# !pip install --upgrade openai
# !pip install --upgrade langchain
# !pip install --upgrade python-dotenv
# !pip install langchain_community
# !pip install langchain
# !pip install openai
# !pip install tiktoken
## Basic Prompt Summarization
from langchain.schema import(AIMessage,HumanMessage,SystemMessage)
import openai
import os
import IPython
from langchain.llms import OpenAI
import os
from openai import OpenAI
open_api_key="sk-proj-QpkpUYCdV0cYlWkd6Ii5T3BlbkFJxqkoAoAiIwlgURWNw6Fn"
os.environ["OPENAI_API_KEY"]=open_api_key
client = OpenAI()

# %%
choice=int(input("""Enter \n 1:Worksheet \n 2:Activity \n 3:Plan \n 4:Test \n 5:Quiz"""))
if choice==1:
  prompt=prompt_worksheet
elif choice==2:
  prompt=prompt_activity
elif choice==3:
  prompt=prompt_plan
elif choice==4:
  prompt=prompt_test
elif choice==5:
  prompt=prompt_quiz
messages = [
    {
        "role": "user",
        "content": prompt
    }
]
response=client.chat.completions.create(model="gpt-3.5-turbo",messages=messages,temperature=0.5,max_tokens=3500,top_p=0.95,frequency_penalty=0,presence_penalty=0,stop=None)
# Out:
# Enter
#  1:Worksheet
#  2:Activity
#  3:Plan
#  4:Test
#  5:Quiz5

# %%
from pprint import pprint
print(response.choices[0].message.content)
# Out:
# English Motivation Quiz
#
# Student Name: ________________________ Date: ____________________
#
# Directions: Choose the correct answer for each question.
#
# 1. What is one way to stay motivated for studying?
# A. Setting achievable goals
# B. Procrastinating
# C. Giving up easily
#
# 2. How can positive self-talk help with motivation?
# A. It can increase self-doubt
# B. It can boost confidence and motivation
# C. It has no effect on motivation
#
# 3. What is the importance of creating a study schedule?
# A. It adds unnecessary stress
# B. It helps with time management and consistency
# C. It doesn't make a difference
#
# 4. How can visualizing success help with motivation?
# A. It can discourage you from trying
# B. It can increase motivation and drive
# C. It has no impact on motivation
#
# 5. Why is it important to take breaks while studying?
# A. To work longer hours without breaks
# B. To prevent burnout and maintain focus
# C. Breaks are unnecessary
#
# Answer Key:
#
# ...

# %%
# basic example
# choice=input("Enter your choice what you want to generate like worksheet, Activity ")
# subject=input("Enter Subject Please")
# grade=input("Enter Grade level Please")
subject="English"
grade='12'
activity="How to stay motivated for study"
prompt_activity = f"""Your Name is Kira, a virtual assistant to help teachers create classroom resources quickly and efficiently.
************here is the demo of activity for Grade 5, Subject English , Activity is Creating a Women Empowerment Storybook**************

Activity: Creating a Women Empowerment Storybook
Objective:

This activity aims to help 5th-grade students understand and appreciate the concept of women empowerment. It's an excellent opportunity for them to demonstrate their understanding by creating a women empowerment storybook. Through this activity, students will reinforce their skills in story writing, character development, elaborating themes, and illustrating ideas.

Instructions:
Step 1: Brainstorming Session (10 minutes)

Students should be divided into groups of four and asked to brainstorm the following:
- Key characteristics of empowered women (Hint: Strength, Independence, Resilience, Intelligence, etc.)
- Major challenges faced by women and how they overcome them.
- Role models of empowered women in their lives or in history.
- Potential storyline including plot, character development, and conclusion.

Step 2: Story Writing (15 minutes)

Each group is now tasked with creating an engaging story reflecting the points discussed above. Include strong women characters and demonstrate how they conquer their challenges.

Step 3: Illustrating ideas and Creating the storybook (10 minutes)

Finally, students will illustrate their stories on paper sheets or cardboard to create their Women Empowerment storybook, using colors, markers, and any other available resources.

Outcome:

By the end of the activity, students will learn the importance of empowering women in society while enhancing their English Language skills. They will also learn how to work collaboratively and appreciate the strength and resilience of women in overcoming obstacles.

Evaluation:

The teacher will evaluate the storybooks based on clarity of the story, creativity, relevance to the topic, and collaborative efforts of the group. Students will present their books by reading the stories aloud and explaining their illustrations.


************************************************************

You've to generate activity for Grade:{grade} suject is {subject} and activitiy is {activity} ,Generate with proper explanation, timeline and completed


"""

prompt_activity =prompt_activity.format(grade=grade,subject=subject,activity=activity)



prompt_quiz=f"""
Your Name is Kira, a virtual assistant to help teachers create classroom resources quickly and efficiently.
************here is the demo of workSheet for Grade-lvele is K, Subject is Foreign Languages, Quiz topic is English Numbers Quiz**************

English Numbers Quiz

Student Name: ________________________ Date: ____________________

Directions: Match the English number with its correct French translation. Draw a line connecting them!

1. one

2. two

3. three

4. four

5. five

A. deux

B. un

C. cinq

D. trois

E. quatre

Directions: Write the French name for the English number.

6. six ____________________

7. seven ___________________

8. eight ___________________

9. nine ___________________

10. ten ___________________

Bonus Question! Write the English word for 'onze'.

____________________

Answer Key:

1. B 2. A 3. D 4. E 5. C 6. six 7. sept 8. huit 9. neuf 10. dix Bonus: eleven

*****************Your Role*******************
Create Quiz for Grade:{grade} suject :{subject} and topic is {activity} with proper right answers
and it should be look like that no one can understand that you're AI model.It should be look like Human generated.
"""


prompt_quiz=prompt_quiz.format(grade=grade,subject=subject,activity=activity)



prompt_worksheet=f"""
Your Name is Kira, a virtual assistant to help teachers create classroom resources quickly and efficiently.
************
You've to generate worksheet for every grade, subject and topic. Please note I'm just sharing demo for your easiness so that you can craft the good worksheet
here is just demo of workSheet for Grade 4, Subject Math , WorkSheet topic is Understanding Fractions Worksheet.
**************

Understanding Fractions Worksheet

Name:_____________
Date:_____________

Learning Objective: Understand what fractions represent and how to draw a fraction using circles and rectangles.

Instructions: Follow the directions for each question. Use the shapes to help you understand the fraction. Draw your answer in the provided space.



Draw a circle and divide it into 2 equal parts. Color one part.
Please mention what fraction you just drew in the space below:

...................................................................................
Draw a rectangle and divide it into 3 equal parts. Color two parts.
What fraction did you color in the rectangle below?

...................................................................................
If you see a pie divided into 4 slices and one of them is eaten, how would write this as a fraction?
Write your fraction below here:

...................................................................................
Draw a picture of 1/3 using a shape of your choice (circle, square, rectangle).
Did you have fun while drawing? Write 'Yes' or 'No' below:

...................................................................................
Draw a picture of half of the pizza eaten.
What fraction of the pizza was eaten? Write your answer below:

...................................................................................

Note:
A fraction shows how many parts of a whole we have. The number on the top is the number of parts we have, and the number on the bottom is how many equal parts the whole is divided into. For example, 1/2 means we have 1 out of 2 parts.0

*****************Your Role*******************
Create WorkSheet for Grade:{grade} suject :{subject} and topic is {activity} ,
Generate this with proper explanation, timeline and completed and it should be look like that no one can understand that you're AI model.

It should be look like Human generated.

"""

prompt_worksheet=prompt_worksheet.format(grade=grade,subject=subject,activity=activity)



prompt_plan=f"""
Your Name is Kira, a virtual assistant to help teachers create classroom resources quickly and efficiently.
************here is the demo of Plan for Grade 3, Subject Math , Plan topic is
                'Real Life Examples Of Fractions'

 **************
Lesson Plan: Real Life Examples Of Fractions
Grade Level: 3

Objective: Students will understand the concept of fractions and be able to use them in real life situations. By the end of the lesson, students will be able to explain and demonstrate their understanding of fractions.

Prerequisite Knowledge: Review of concepts related to whole numbers including addition, subtraction, division and multiplication.

New Information: Introduce the concept of fractions - what is a numerator and what is a denominator. Discuss how fractions are used in daily life to divide objects or sets of objects into equal parts.

Teaching/Learning Activities:
Begin with an explanation and demonstration of what fractions are and how we use them in real life. Use objects such as apples, pies or chocolates for modeling.
Break the students into three groups (low, average, advanced) and give them different fraction-related tasks based on their skill level. For the low-skilled group, the task could be simple fraction identification, the average group could be assigned the task of adding and subtracting fractions with the same denominators, while the advanced group could work with fractions with different denominators.
Encourage students to come up with their own real-life examples of fractions.
Use worksheets, games and practical activities to reinforce the concept of fractions.
Checking for Understanding:
Ask students to explain or demonstrate the concept of fractions.
Monitor their group activities and offer correction and guidance where necessary.
Assess their individual and group assignments.
Conduct a quick quiz or test to evaluate their understanding of fractions.

Expecations: Students should be able to explain what fractions are and use real life examples to demonstrate their understanding. They should be able to solve simple problems involving fractions.

*****************Your Role*******************
Create Plan for Grade:{grade} suject :{subject} and topic is {activity} with proper explanation, timeline and completed.



 """


prompt_plan=prompt_plan.format(grade=grade,subject=subject,activity=activity)



prompt_test=f"""
Your Name is Kira, a virtual assistant to help teachers create classroom resources quickly and efficiently.
************here is the demo of Quiz for Grade 5, Subject English , Test topic is
                'Create a Women Empowerment Storybook'**************

3rd Grade English Test on Women's Empowerment

Name:
Date:

Instructions:

Please read each question carefully and answer in full sentences on the lines provided. Bondus questions are optional but can provide extra points. Don't forget to check your spelling!

Comprehension Questions:

1. Who is one famous woman that you admire and why?

2. What are some characteristics or abilities that show a woman is empowered?

3. From your reading assignment, describe how the main character demonstrated women's empowerment.

4. Can men and boys support women's empowerment? Write 2 ways they can do this from your learning material.
Bonus Question:
Write a brief sentence about Malala Yousafzai's contribution to women's empowerment.

Answer Key
Comprehension Questions:
1. Answers may vary. Students should describe a noted influential woman and provide reasons why they admire her.

2. Answers will vary, but may include aspects such as self-confidence, independence, control over personal life, ability to make life choices, etc.

3. Answers will vary depending on the reading assignment. Students should address ways the main character shows empowerment or growth.

4. Answers will vary but can include support like speaking out against gender discrimination, respecting women's rights, advocating for girls' education, etc.

Bonus: Malala Yousafzai has significantly contributed to women's empowerment by advocating for girls' education, even in the face of adversity. She is the youngest-ever Nobel Prize laureate.
*****************Your Role*******************
Create Quiz for Grade:{grade} suject :{subject} and topic is {activity} with proper explanation, timeline and completed.

"""
prompt_test=prompt_test.format(grade=grade,subject=subject,activity=activity)
